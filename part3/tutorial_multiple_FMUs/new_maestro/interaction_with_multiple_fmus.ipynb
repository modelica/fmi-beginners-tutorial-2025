# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/modelica/fmi-beginners-tutorial-2025/blob/main/part3/tutorial_multiple_FMUs/new_maestro/interaction_with_multiple_fmus.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Running Co-simulations with the INTO-CPS Maestro Co-simulation Engine
#
# The goal of this notebook is to highlight how to run a co-simulation using an open source tool.
#
# It is meant to represent one of the simplest ways to get started running co-simulations with a command line tool.
#
# The notebook is organized into two parts:
# 1. The first part is focused on running a co-simulation from the command line without concern for the accuracy of the results.
# 2. The second part shows how the accuracy of the co-simulation can be measured provided that there exists a baseline reference.
#
# Running a co-simulation using the INTO-CPS co-simulation orchestration requires the user to specify the co-simulation scenario in a JSON file, which is then fed into the tool which will load the FMUS and produce the results as a CSV file.

# %%
# Import all dependencies
import json
import subprocess
import pandas
import matplotlib.pyplot as plt
import numpy as np
import time

# %%
# %%bash
git clone https://github.com/modelica/fmi-beginners-tutorial-2025.git

# %%
# Small details: make the jar executable in your platform.
# %cd fmi-beginners-tutorial-2025/part3/tutorial_multiple_FMUs/new_maestro
coe_jar = "maestro.jar"

# Make jar executable.
#command = f"chmod +x {coe_jar}"
#result = subprocess.run(command, shell=True, capture_output=True, text=True)
#if result.returncode != 0:
#    raise RuntimeError(f"Error running command {command}: {result.stderr}")

def simulate(config_path, start_time, end_time):
    import json

    data = {
        "startTime": start_time,
        "endTime": end_time
    }
    
    with open("run.json", "w") as f:
        json.dump(data, f, indent=2)
    
    coe_command = f"java -jar maestro.jar import sg1 --fmu-search-path fmus {config_path} run.json --interpret"
    result = subprocess.run(coe_command, shell=True, capture_output=True, text=True)
    
    
    # Check the command's output
    if result.returncode == 0:
        import os
        os.rename('outputs.csv', 'output.csv')
        print(result.stdout)
    else:
        raise RuntimeError(f"Error running command {coe_command}: {result.stderr}")
# Out:
# [Errno 2] No such file or directory: 'fmi-beginners-tutorial-2025/part3/tutorial_multiple_FMUs'
# /app

# %% [markdown]
# ## Part 1: Running Co-simulations from the Command Line
#
# This part is divided into 2 sections:
# 1. Running a co-simulation of a single FMU.
# 2. Running a co-simulation with multiple interconnected FMUs.

# %% [markdown]
# ### Running Co-simulations with Single FMU

# %%
# Prepare the co-simulation scenario description, which points to where the FMU.
singlefmu_scenario_json_file = "single_fmu_scenario.json"

# The following is a small detail whereby we need to find the absolute path of the FMU that is compatible with the platform of the user.
platform_folder = 'Linux'
# We can now see the co-simulation scenario as a json file:
with open(singlefmu_scenario_json_file, 'r') as file :
    scenario_raw = file.read()

print(json.dumps(json.loads(scenario_raw), indent=2))
# Out:
# {
#   "fmus": {
#     "{baseline}": "./fmus/MODELICA_Demo.ControlledElectricDrive.fmu"
#   },
#   "connections": {},
#   "parameters": {},
#   "logVariables": {
#     "{baseline}.baselineInstance": [
#       "w"
#     ]
#   },
#   "algorithm": {
#     "type": "fixed-step",
#     "size": 0.001
#   },
#   "loggingOn": false,
#   "overrideLogLevel": "INFO"
# }

# %%
# Now we can run the co-simulation
#coe_command = f"java -jar {coe_jar} --oneshot --configuration {singlefmu_scenario_json_file} --starttime 0 --endtime 1 --result output.csv"
simulate(singlefmu_scenario_json_file,0,1)
# import json

# data = {
#     "startTime": 0,
#     "endTime": 1.0
# }

# with open("run.json", "w") as f:
#     json.dump(data, f, indent=2)

# coe_command = f"java -jar maestro-4.0.1-SNAPSHOT-jar-with-dependencies.jar import sg1 --fmu-search-path fmus {singlefmu_scenario_json_file} run.json --interpret"
# result = subprocess.run(coe_command, shell=True, capture_output=True, text=True)


# # Check the command's output
# if result.returncode == 0:
#     print(result.stdout)
# else:
#     raise RuntimeError(f"Error running command {coe_command}: {result.stderr}")
# Out:
# 08:42:37.009 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:42:37.249 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:42:37.481 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:42:37.481 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:42:37.481 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:42:37.481 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:42:37.482 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:42:37.482 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:42:37.482 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:42:37.493 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [JacobianStepBuilder3-1.1.0,DebugLogging-0.0.1,TypeConverter-0.0.1,Initializer-0.0.0,JacobianStepBuilder-1.1.0]
# 08:42:37.495 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# DebugLogging-0.0.1
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# TypeConverter-0.0.1
# 	void convertReal2Boolean(real from, bool to),
# 	void convertBoolean2Integer(bool from, int to),
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:42:37.541 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:42:37.548 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:42:37.594 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:42:37.778 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:42:37.814 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:42:37.845 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:42:37.845 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:42:38.656 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:42:38.741 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:42:38.758 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu
# 08:42:38.759 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu to /tmp/MODELICA_Demo9074978314085423935
# 08:42:38.913 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu' to '/tmp/MODELICA_Demo9074978314085423935'
# 08:42:38.929 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/MODELICA_Demo9074978314085423935/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:42:38.929 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:42:38.930 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:42:38.940 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi13142709009538466735/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:38.941 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi13142709009538466735/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:38.944 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/MODELICA_Demo9074978314085423935/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:42:38.945 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140264048515568
# 08:42:38.945 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 188014384
# 08:42:38.946 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {e50d67b1-f0fd-4cb9-b790-439045eb253b}, NAME: baselineInstance
# 08:42:38.953 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 6629756
# 08:42:39.152 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:39.153 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:39.153 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu, temp folder /tmp/MODELICA_Demo9074978314085423935
# 08:42:39.154 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/MODELICA_Demo9074978314085423935
# 08:42:39.168 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 425989996 PT0.425983462S

# %%
# We can see the results stored in "output.csv"
data = pandas.read_csv("output.csv")
data
# Out:
#       time  {baseline}.baselineInstance.w
# 0    0.000                            0.0
# 1    0.001                            0.0
# 2    0.002                            0.0
# 3    0.003                            0.0
# 4    0.004                            0.0
# ..     ...                            ...
# 995  0.995                           10.0
# 996  0.996                           10.0
# 997  0.997                           10.0
# 998  0.998                           10.0
# 999  0.999                           10.0
#
# [1000 rows x 2 columns]

# %%
# As can can plot those results as follows
plt.figure()
plt.plot(data["time"], data["{baseline}.baselineInstance.w"], label="{baseline}.w")
plt.legend()
plt.show()

# %% [markdown]
# ### Running a Co-simulation with Multiple FMUs

# %%
# Prepare the co-simulation scenario description, which points to where the FMUs are.

decoupled_scenario_json_file = "decoupled_scenario.json"

# We can now see the co-simulation scenario as a json file:
with open(decoupled_scenario_json_file, 'r') as file :
    scenario_raw = file.read()

print(json.dumps(json.loads(scenario_raw), indent=2))
# Out:
# {
#   "fmus": {
#     "{stimuli}": "./fmus/Stimuli.fmu",
#     "{control}": "./fmus/Control.fmu",
#     "{drive}": "./fmus/Drive.fmu"
#   },
#   "connections": {
#     "{stimuli}.stimuliInstance.w_desired": [
#       "{control}.controlInstance.w_desired"
#     ],
#     "{stimuli}.stimuliInstance.LoadTorque_Nm": [
#       "{drive}.driveInstance.LoadTorque_Nm"
#     ],
#     "{control}.controlInstance.V": [
#       "{drive}.driveInstance.V"
#     ],
#     "{drive}.driveInstance.w": [
#       "{control}.controlInstance.w"
#     ]
#   },
#   "parameters": {},
#   "algorithm": {
#     "type": "fixed-step",
#     "size": 0.001
#   },
#   "loggingOn": false,
#   "overrideLogLevel": "INFO"
# }

# %%
# Now we can run the co-simulation
# coe_command = f"java -jar {coe_jar} --oneshot --configuration {decoupled_scenario_json_file} --starttime 0 --endtime 1 --result output.csv"
# result = subprocess.run(coe_command, shell=True, capture_output=True, text=True)

# # Check the command's output
# if result.returncode == 0:
#     print(result.stdout)
# else:
#     raise RuntimeError(f"Error running command {coe_command}: {result.stderr}")
simulate(decoupled_scenario_json_file,0,1)
# Out:
# 08:42:41.074 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:42:41.325 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:42:41.570 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:42:41.570 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:42:41.570 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:42:41.570 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:42:41.571 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:42:41.571 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:42:41.571 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:42:41.582 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [DebugLogging-0.0.1,TypeConverter-0.0.1,JacobianStepBuilder3-1.1.0,JacobianStepBuilder-1.1.0,Initializer-0.0.0]
# 08:42:41.584 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# DebugLogging-0.0.1
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# TypeConverter-0.0.1
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# 	void convertBoolean2Integer(bool from, int to),
# 	void convertReal2Boolean(real from, bool to),
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined),
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:42:41.629 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:42:41.635 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:42:41.683 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:42:41.834 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:42:41.877 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:42:41.898 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:42:41.899 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:42:42.763 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:42:42.879 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:42:42.891 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Stimuli.fmu
# 08:42:42.892 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Stimuli.fmu to /tmp/Stimuli9885179411150850274
# 08:42:43.012 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Stimuli.fmu' to '/tmp/Stimuli9885179411150850274'
# 08:42:43.017 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Stimuli9885179411150850274/binaries/linux64/Stimuli.so
# 08:42:43.018 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:42:43.018 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:42:43.027 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi8604596323393426714/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:43.029 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi8604596323393426714/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:43.030 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Stimuli9885179411150850274/binaries/linux64/Stimuli.so
# 08:42:43.030 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139788783814656
# 08:42:43.031 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 140256448
# 08:42:43.032 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Drive.fmu
# 08:42:43.032 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Drive.fmu to /tmp/Drive12350881034234586424
# 08:42:43.121 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Drive.fmu' to '/tmp/Drive12350881034234586424'
# 08:42:43.130 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Drive12350881034234586424/binaries/linux64/Drive.so
# 08:42:43.130 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Drive12350881034234586424/binaries/linux64/Drive.so
# 08:42:43.130 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139788783571952
# 08:42:43.131 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 99446264
# 08:42:43.131 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Control.fmu
# 08:42:43.131 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Control.fmu to /tmp/Control14912149397062028933
# 08:42:43.211 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Control.fmu' to '/tmp/Control14912149397062028933'
# 08:42:43.214 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Control14912149397062028933/binaries/linux64/Control.so
# 08:42:43.215 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Control14912149397062028933/binaries/linux64/Control.so
# 08:42:43.215 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139788783574640
# 08:42:43.215 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 84701051
# 08:42:43.216 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {14d4dba8-0226-412e-8fda-5f49a32d04a2}, NAME: stimuliInstance
# 08:42:43.223 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 7015064
# 08:42:43.226 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {7ef1310e-51ff-43f0-81ad-cd309eb2ca4f}, NAME: controlInstance
# 08:42:43.228 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 2154503
# 08:42:43.228 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {126aa57a-b271-41f4-a011-9fd7bfeae4ea}, NAME: driveInstance
# 08:42:43.230 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 2389670
# 08:42:46.070 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:46.070 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:46.071 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:46.071 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:46.071 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Stimuli.fmu, temp folder /tmp/Stimuli9885179411150850274
# 08:42:46.072 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Stimuli9885179411150850274
# 08:42:46.084 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:46.085 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Drive.fmu, temp folder /tmp/Drive12350881034234586424
# 08:42:46.085 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Drive12350881034234586424
# 08:42:46.094 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:46.094 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Control.fmu, temp folder /tmp/Control14912149397062028933
# 08:42:46.094 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Control14912149397062028933
# 08:42:46.107 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 3226946285 PT3.226941006S

# %%
# If all went well, we can see the results stored in "output.csv"
data = pandas.read_csv("output.csv")
data
# Out:
#       time  {stimuli}.stimuliInstance.w_desired  \
# 0    0.000                                  0.0
# 1    0.001                                  0.0
# 2    0.002                                  0.0
# 3    0.003                                  0.0
# 4    0.004                                  0.0
# ..     ...                                  ...
# 995  0.995                                 10.0
# 996  0.996                                 10.0
# 997  0.997                                 10.0
# 998  0.998                                 10.0
# 999  0.999                                 10.0
#
#      {stimuli}.stimuliInstance.LoadTorque_Nm  {control}.controlInstance.V  \
# 0                                        0.0                     0.000000
# 1                                        0.0                     0.000000
# 2                                        0.0                     0.000000
# 3                                        0.0                     0.000000
# 4                                        0.0                     0.000000
# ..                                       ...                          ...
# 995                                      3.0                     5.963236
# 996                                      3.0                     5.963236
# 997                                      3.0                     5.963236
# 998                                      3.0                     5.963236
# 999                                      3.0                     5.963236
#
#      {drive}.driveInstance.w
# 0                   0.000000
# 1                   0.000000
# 2                   0.000000
# 3                   0.000000
# 4                   0.000000
# ..                       ...
# 995                10.000001
# 996                10.000001
# 997                10.000001
# 998                10.000001
# 999                10.000001
#
# [1000 rows x 5 columns]

# %%
# As can can plot those results as follows
plt.figure()
plt.plot(data["time"], data["{drive}.driveInstance.w"], label="{drive}.w")
plt.plot(data["time"], data["{stimuli}.stimuliInstance.w_desired"], label="{stimuli}.w_desired")
plt.legend()
plt.show()

# %% [markdown]
# ## Part 2: Measuring Accuracy of the Co-simulation Wrt to Baseline
#
# In this part we show how to measure the accuracy of a co-simulation and the impact of the co-simulation step size in the accuracy.
# We have two sections:
# 1. We run a co-simulation scenario where we include the baseline as an FMU that is run in parallel with the other fmus, that are representing the same system, but in a decoupled manner.
# 2. In the second section we run multiple experiments with different communication steps in order to highlight the impact of this parameter in the accuracy.

# %% [markdown]
# ### Co-simulation Scenario with Baseline

# %%
# Prepare the co-simulation scenario description, which points to where the FMUs are.
baseline_scenario_json_template = "baseline_scenario_template.json"
baseline_scenario_json_file = "baseline_scenario.json"

# We can now see the co-simulation scenario as a json file:
with open(baseline_scenario_json_file, 'r') as file:
    scenario_raw = file.read()

print(json.dumps(json.loads(scenario_raw), indent=2))
# Out:
# {
#   "fmus": {
#     "{stimuli}": "./fmus/Stimuli.fmu",
#     "{control}": "./fmus/Control.fmu",
#     "{drive}": "./fmus/Drive.fmu",
#     "{baseline}": "./fmus/MODELICA_Demo.ControlledElectricDrive.fmu"
#   },
#   "connections": {
#     "{stimuli}.stimuliInstance.w_desired": [
#       "{control}.controlInstance.w_desired"
#     ],
#     "{stimuli}.stimuliInstance.LoadTorque_Nm": [
#       "{drive}.driveInstance.LoadTorque_Nm"
#     ],
#     "{control}.controlInstance.V": [
#       "{drive}.driveInstance.V"
#     ],
#     "{drive}.driveInstance.w": [
#       "{control}.controlInstance.w"
#     ]
#   },
#   "parameters": {},
#   "logVariables": {
#     "{baseline}.baselineInstance": [
#       "w"
#     ],
#     "{drive}.driveInstance": [
#       "w"
#     ],
#     "{stimuli}.stimuliInstance": [
#       "w_desired"
#     ]
#   },
#   "algorithm": {
#     "type": "fixed-step",
#     "size": 0.001
#   },
#   "loggingOn": false,
#   "overrideLogLevel": "INFO"
# }

# %%
# Now we can run the co-simulation
# coe_command = f"java -jar {coe_jar} --oneshot --configuration  {baseline_scenario_json_file} --starttime 0 --endtime 1 --result output.csv"
# result = subprocess.run(coe_command, shell=True, capture_output=True, text=True)

# # Check the command's output
# if result.returncode == 0:
#     print(result.stdout)
# else:
#     raise RuntimeError(f"Error running command {coe_command}: {result.stderr}")
simulate(baseline_scenario_json_file,0,1)
# Out:
# 08:42:48.349 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:42:48.766 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:42:49.030 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:42:49.030 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:42:49.031 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:42:49.031 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:42:49.031 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:42:49.031 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:42:49.031 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:42:49.042 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [Initializer-0.0.0,DebugLogging-0.0.1,JacobianStepBuilder3-1.1.0,TypeConverter-0.0.1,JacobianStepBuilder-1.1.0]
# 08:42:49.044 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined),
# DebugLogging-0.0.1
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# TypeConverter-0.0.1
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertReal2Boolean(real from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# 	void convertBoolean2Integer(bool from, int to),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:42:49.090 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:42:49.096 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:42:49.151 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:42:49.386 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:42:49.448 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:42:49.479 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:42:49.479 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:42:51.600 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:42:51.787 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:42:51.800 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Stimuli.fmu
# 08:42:51.800 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Stimuli.fmu to /tmp/Stimuli10726403682752173352
# 08:42:51.919 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Stimuli.fmu' to '/tmp/Stimuli10726403682752173352'
# 08:42:51.929 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Stimuli10726403682752173352/binaries/linux64/Stimuli.so
# 08:42:51.929 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:42:51.930 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:42:51.937 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi2798139957884993611/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:51.939 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi2798139957884993611/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:51.940 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Stimuli10726403682752173352/binaries/linux64/Stimuli.so
# 08:42:51.940 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140657641849808
# 08:42:51.941 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 141412200
# 08:42:51.941 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Drive.fmu
# 08:42:51.942 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Drive.fmu to /tmp/Drive11682357365200660850
# 08:42:52.029 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Drive.fmu' to '/tmp/Drive11682357365200660850'
# 08:42:52.039 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Drive11682357365200660850/binaries/linux64/Drive.so
# 08:42:52.040 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Drive11682357365200660850/binaries/linux64/Drive.so
# 08:42:52.040 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140657641876880
# 08:42:52.040 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 99667484
# 08:42:52.041 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu
# 08:42:52.041 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu to /tmp/MODELICA_Demo1374279586954702471
# 08:42:52.108 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu' to '/tmp/MODELICA_Demo1374279586954702471'
# 08:42:52.116 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/MODELICA_Demo1374279586954702471/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:42:52.120 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/MODELICA_Demo1374279586954702471/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:42:52.120 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140657642197152
# 08:42:52.120 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 79540912
# 08:42:52.121 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Control.fmu
# 08:42:52.122 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Control.fmu to /tmp/Control6799313170124844108
# 08:42:52.188 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Control.fmu' to '/tmp/Control6799313170124844108'
# 08:42:52.190 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Control6799313170124844108/binaries/linux64/Control.so
# 08:42:52.191 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Control6799313170124844108/binaries/linux64/Control.so
# 08:42:52.191 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140657641900528
# 08:42:52.191 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 70288659
# 08:42:52.192 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {e50d67b1-f0fd-4cb9-b790-439045eb253b}, NAME: baselineInstance
# 08:42:52.197 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 5726964
# 08:42:52.200 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {14d4dba8-0226-412e-8fda-5f49a32d04a2}, NAME: stimuliInstance
# 08:42:52.202 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1945383
# 08:42:52.203 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {126aa57a-b271-41f4-a011-9fd7bfeae4ea}, NAME: driveInstance
# 08:42:52.204 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1424141
# 08:42:52.204 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {7ef1310e-51ff-43f0-81ad-cd309eb2ca4f}, NAME: controlInstance
# 08:42:52.206 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1217857
# 08:42:52.543 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:52.544 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:52.544 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:52.545 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:52.546 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:52.546 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Stimuli.fmu, temp folder /tmp/Stimuli10726403682752173352
# 08:42:52.546 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Stimuli10726403682752173352
# 08:42:52.558 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:52.558 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Drive.fmu, temp folder /tmp/Drive11682357365200660850
# 08:42:52.559 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Drive11682357365200660850
# 08:42:52.567 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:52.567 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu, temp folder /tmp/MODELICA_Demo1374279586954702471
# 08:42:52.568 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/MODELICA_Demo1374279586954702471
# 08:42:52.576 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:52.576 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Control.fmu, temp folder /tmp/Control6799313170124844108
# 08:42:52.576 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Control6799313170124844108
# 08:42:52.582 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 794848786 PT0.794844807S

# %%
# If all went well, we can see the results stored in "output.csv"
data = pandas.read_csv("output.csv")
data
# Out:
#       time  {baseline}.baselineInstance.w  \
# 0    0.000                            0.0
# 1    0.001                            0.0
# 2    0.002                            0.0
# 3    0.003                            0.0
# 4    0.004                            0.0
# ..     ...                            ...
# 995  0.995                           10.0
# 996  0.996                           10.0
# 997  0.997                           10.0
# 998  0.998                           10.0
# 999  0.999                           10.0
#
#      {stimuli}.stimuliInstance.w_desired  {drive}.driveInstance.w
# 0                                    0.0                 0.000000
# 1                                    0.0                 0.000000
# 2                                    0.0                 0.000000
# 3                                    0.0                 0.000000
# 4                                    0.0                 0.000000
# ..                                   ...                      ...
# 995                                 10.0                10.000001
# 996                                 10.0                10.000001
# 997                                 10.0                10.000001
# 998                                 10.0                10.000001
# 999                                 10.0                10.000001
#
# [1000 rows x 4 columns]

# %%
# And we can plot those results as follows

plt.figure()
plt.plot(data["time"], data["{baseline}.baselineInstance.w"], label="{baseline}.w")
plt.plot(data["time"], data["{drive}.driveInstance.w"], label="{drive}.w")
plt.plot(data["time"], data["{stimuli}.stimuliInstance.w_desired"], label="{stimuli}.w_desired")
plt.legend()
plt.show()

# %%
# Now we measure the error and print it:

def error(ref_series, approx_series):
    error_signal = ref_series.to_numpy() - approx_series.to_numpy()
    sum_squared_differences = np.sum(error_signal ** 2)
    return sum_squared_differences

error(data["{baseline}.baselineInstance.w"], data["{drive}.driveInstance.w"])
# Out:
# np.float64(8.21990534534943)

# %% [markdown]
# ### Impact of Step Size in the Accuracy
#
# This section is a bit more advanced.
# What we want is to run many simulations with different step sizes, and for each of these runs, we want to collect the results, calculate their error and store it.
# Then, we can create a plot that compares the different step sizes with the achieved error.

# %%
# So we need a function to run a full experiment given a step size.
def searchAndReplace(key, value, fileSrc, fileTrg):
  '''
  Opens a file fileSrc and searches for all occurrences of key string and replaces it by value.
  Stores the result in fileTrg.
  '''
  with open(fileSrc, 'r') as file :
    filedata = file.read()

  filedata = filedata.replace(key, value)

  with open(fileTrg, 'w') as file:
    file.write(filedata)

def run_experiment_with_step_size(step_size):
  # Set the step size in the config file:
  searchAndReplace("0.001", str(step_size), baseline_scenario_json_template, baseline_scenario_json_file)

  start_time_seconds = time.time()
  simulate(baseline_scenario_json_file,0,1)
  #result = subprocess.run(coe_command, shell=True, capture_output=True, text=True)
  elapsed_time_seconds = time.time() - start_time_seconds

  # Check for failure and print debug information
  if result.returncode != 0:
    with open(baseline_scenario_json_file, 'r') as file:
        scenario_raw = file.read()
    raise RuntimeError(f"Error running command {coe_command} for step size {step_size}: {result.stderr}. \nThe input scenario is:\n{json.dumps(json.loads(scenario_raw), indent=2)}")

  # Read results and compute error
  data = pandas.read_csv("output.csv")

  return error(data["{baseline}.baselineInstance.w"], data["{drive}.driveInstance.w"]), elapsed_time_seconds

# Define possible step sizes we wish to try.
step_sizes = np.linspace(0.0001, 0.001, 4)
print(f"step_sizes = {step_sizes}")

# Run an experiment for each step size. CAUTION: this takes time.
results = [run_experiment_with_step_size(step_size) for step_size in step_sizes]
errors = [r[0] for r in results]
execution_times = [r[1] for r in results]

print(f"errors = {errors}")
print(f"execution_times = {execution_times}")
# Out:
# step_sizes = [0.0001 0.0004 0.0007 0.001 ]
# 08:42:54.686 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:42:55.087 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:42:55.345 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:42:55.345 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:42:55.346 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:42:55.346 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:42:55.346 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:42:55.346 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:42:55.346 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:42:55.358 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [Initializer-0.0.0,DebugLogging-0.0.1,JacobianStepBuilder3-1.1.0,TypeConverter-0.0.1,JacobianStepBuilder-1.1.0]
# 08:42:55.359 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined),
# DebugLogging-0.0.1
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# TypeConverter-0.0.1
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertReal2Boolean(real from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# 	void convertBoolean2Integer(bool from, int to),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:42:55.400 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:42:55.406 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:42:55.459 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:42:55.695 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:42:55.753 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:42:55.785 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:42:55.785 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:42:57.770 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:42:57.947 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:42:57.959 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Stimuli.fmu
# 08:42:57.959 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Stimuli.fmu to /tmp/Stimuli8065707234027634478
# 08:42:58.070 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Stimuli.fmu' to '/tmp/Stimuli8065707234027634478'
# 08:42:58.076 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Stimuli8065707234027634478/binaries/linux64/Stimuli.so
# 08:42:58.077 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:42:58.077 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:42:58.084 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi17865497105609130615/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:58.086 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi17865497105609130615/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:42:58.087 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Stimuli8065707234027634478/binaries/linux64/Stimuli.so
# 08:42:58.087 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139746367122592
# 08:42:58.087 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 128914111
# 08:42:58.088 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Drive.fmu
# 08:42:58.088 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Drive.fmu to /tmp/Drive11139052529724454174
# 08:42:58.176 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Drive.fmu' to '/tmp/Drive11139052529724454174'
# 08:42:58.185 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Drive11139052529724454174/binaries/linux64/Drive.so
# 08:42:58.186 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Drive11139052529724454174/binaries/linux64/Drive.so
# 08:42:58.186 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139746367068208
# 08:42:58.186 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 98527572
# 08:42:58.187 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu
# 08:42:58.187 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu to /tmp/MODELICA_Demo11203352795988091341
# 08:42:58.250 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu' to '/tmp/MODELICA_Demo11203352795988091341'
# 08:42:58.256 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/MODELICA_Demo11203352795988091341/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:42:58.259 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/MODELICA_Demo11203352795988091341/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:42:58.259 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139746367174736
# 08:42:58.259 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 72725449
# 08:42:58.260 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Control.fmu
# 08:42:58.260 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Control.fmu to /tmp/Control993631937148988679
# 08:42:58.324 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Control.fmu' to '/tmp/Control993631937148988679'
# 08:42:58.327 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Control993631937148988679/binaries/linux64/Control.so
# 08:42:58.328 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Control993631937148988679/binaries/linux64/Control.so
# 08:42:58.328 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 139746371165168
# 08:42:58.328 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 68804822
# 08:42:58.329 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {e50d67b1-f0fd-4cb9-b790-439045eb253b}, NAME: baselineInstance
# 08:42:58.334 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 5575216
# 08:42:58.337 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {14d4dba8-0226-412e-8fda-5f49a32d04a2}, NAME: stimuliInstance
# 08:42:58.339 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1894001
# 08:42:58.340 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {126aa57a-b271-41f4-a011-9fd7bfeae4ea}, NAME: driveInstance
# 08:42:58.341 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1348473
# 08:42:58.341 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {7ef1310e-51ff-43f0-81ad-cd309eb2ca4f}, NAME: controlInstance
# 08:42:58.343 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1417244
# 08:42:59.401 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:59.401 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:59.402 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:59.403 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:42:59.403 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:59.403 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Stimuli.fmu, temp folder /tmp/Stimuli8065707234027634478
# 08:42:59.404 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Stimuli8065707234027634478
# 08:42:59.417 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:59.417 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Drive.fmu, temp folder /tmp/Drive11139052529724454174
# 08:42:59.417 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Drive11139052529724454174
# 08:42:59.426 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:59.427 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu, temp folder /tmp/MODELICA_Demo11203352795988091341
# 08:42:59.427 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/MODELICA_Demo11203352795988091341
# 08:42:59.436 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:42:59.436 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Control.fmu, temp folder /tmp/Control993631937148988679
# 08:42:59.436 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Control993631937148988679
# 08:42:59.442 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 1494751777 PT1.494747112S
#
# 08:43:01.370 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:43:01.766 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:43:02.007 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:43:02.007 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:43:02.007 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:43:02.007 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:43:02.007 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:43:02.007 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:43:02.008 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:43:02.018 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [Initializer-0.0.0,DebugLogging-0.0.1,JacobianStepBuilder3-1.1.0,TypeConverter-0.0.1,JacobianStepBuilder-1.1.0]
# 08:43:02.020 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined),
# DebugLogging-0.0.1
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# TypeConverter-0.0.1
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertReal2Boolean(real from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# 	void convertBoolean2Integer(bool from, int to),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:43:02.063 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:43:02.069 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:43:02.122 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:43:02.356 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:43:02.413 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:43:02.444 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:43:02.445 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:43:04.356 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:43:04.519 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:43:04.530 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Stimuli.fmu
# 08:43:04.531 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Stimuli.fmu to /tmp/Stimuli2193129666908932943
# 08:43:04.653 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Stimuli.fmu' to '/tmp/Stimuli2193129666908932943'
# 08:43:04.658 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Stimuli2193129666908932943/binaries/linux64/Stimuli.so
# 08:43:04.659 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:43:04.660 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:43:04.667 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi7947511053114943507/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:43:04.669 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi7947511053114943507/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:43:04.669 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Stimuli2193129666908932943/binaries/linux64/Stimuli.so
# 08:43:04.669 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140157145904400
# 08:43:04.670 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 140463103
# 08:43:04.671 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Drive.fmu
# 08:43:04.671 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Drive.fmu to /tmp/Drive403319390046717375
# 08:43:04.755 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Drive.fmu' to '/tmp/Drive403319390046717375'
# 08:43:04.763 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Drive403319390046717375/binaries/linux64/Drive.so
# 08:43:04.764 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Drive403319390046717375/binaries/linux64/Drive.so
# 08:43:04.764 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140157135473600
# 08:43:04.765 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 94170141
# 08:43:04.765 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu
# 08:43:04.766 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu to /tmp/MODELICA_Demo13963529105225478746
# 08:43:04.826 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu' to '/tmp/MODELICA_Demo13963529105225478746'
# 08:43:04.832 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/MODELICA_Demo13963529105225478746/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:43:04.835 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/MODELICA_Demo13963529105225478746/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:43:04.835 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140157135464656
# 08:43:04.835 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 70263133
# 08:43:04.836 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Control.fmu
# 08:43:04.836 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Control.fmu to /tmp/Control3727172767956007102
# 08:43:04.893 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Control.fmu' to '/tmp/Control3727172767956007102'
# 08:43:04.895 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Control3727172767956007102/binaries/linux64/Control.so
# 08:43:04.896 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Control3727172767956007102/binaries/linux64/Control.so
# 08:43:04.896 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140157135462496
# 08:43:04.896 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 60676253
# 08:43:04.897 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {e50d67b1-f0fd-4cb9-b790-439045eb253b}, NAME: baselineInstance
# 08:43:04.905 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 7345321
# 08:43:04.908 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {14d4dba8-0226-412e-8fda-5f49a32d04a2}, NAME: stimuliInstance
# 08:43:04.909 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1609617
# 08:43:04.910 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {126aa57a-b271-41f4-a011-9fd7bfeae4ea}, NAME: driveInstance
# 08:43:04.912 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1961393
# 08:43:04.912 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {7ef1310e-51ff-43f0-81ad-cd309eb2ca4f}, NAME: controlInstance
# 08:43:04.914 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1884832
# 08:43:05.326 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:05.327 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:05.327 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:05.328 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:05.328 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:05.328 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Stimuli.fmu, temp folder /tmp/Stimuli2193129666908932943
# 08:43:05.329 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Stimuli2193129666908932943
# 08:43:05.343 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:05.343 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Drive.fmu, temp folder /tmp/Drive403319390046717375
# 08:43:05.343 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Drive403319390046717375
# 08:43:05.353 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:05.353 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu, temp folder /tmp/MODELICA_Demo13963529105225478746
# 08:43:05.354 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/MODELICA_Demo13963529105225478746
# 08:43:05.365 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:05.365 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Control.fmu, temp folder /tmp/Control3727172767956007102
# 08:43:05.365 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Control3727172767956007102
# 08:43:05.370 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 850426055 PT0.850421486S
#
# 08:43:07.290 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:43:07.687 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:43:07.930 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:43:07.931 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:43:07.931 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:43:07.931 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:43:07.931 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:43:07.931 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:43:07.932 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:43:07.943 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [Initializer-0.0.0,DebugLogging-0.0.1,JacobianStepBuilder3-1.1.0,TypeConverter-0.0.1,JacobianStepBuilder-1.1.0]
# 08:43:07.945 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined),
# DebugLogging-0.0.1
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# TypeConverter-0.0.1
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertReal2Boolean(real from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# 	void convertBoolean2Integer(bool from, int to),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:43:07.986 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:43:07.992 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:43:08.042 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:43:08.273 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:43:08.326 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:43:08.356 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:43:08.357 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:43:10.272 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:43:10.431 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:43:10.443 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Stimuli.fmu
# 08:43:10.443 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Stimuli.fmu to /tmp/Stimuli5800003627925475887
# 08:43:10.562 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Stimuli.fmu' to '/tmp/Stimuli5800003627925475887'
# 08:43:10.566 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Stimuli5800003627925475887/binaries/linux64/Stimuli.so
# 08:43:10.568 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:43:10.568 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:43:10.576 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi12704793714618569784/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:43:10.577 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi12704793714618569784/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:43:10.578 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Stimuli5800003627925475887/binaries/linux64/Stimuli.so
# 08:43:10.578 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140140704782352
# 08:43:10.579 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 136306575
# 08:43:10.579 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Drive.fmu
# 08:43:10.579 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Drive.fmu to /tmp/Drive12043118279900462021
# 08:43:10.664 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Drive.fmu' to '/tmp/Drive12043118279900462021'
# 08:43:10.674 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Drive12043118279900462021/binaries/linux64/Drive.so
# 08:43:10.675 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Drive12043118279900462021/binaries/linux64/Drive.so
# 08:43:10.675 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140140689378320
# 08:43:10.675 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 96350529
# 08:43:10.676 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu
# 08:43:10.676 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu to /tmp/MODELICA_Demo705253361978075827
# 08:43:10.747 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu' to '/tmp/MODELICA_Demo705253361978075827'
# 08:43:10.754 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/MODELICA_Demo705253361978075827/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:43:10.756 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/MODELICA_Demo705253361978075827/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:43:10.757 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140140692524480
# 08:43:10.757 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 81425096
# 08:43:10.758 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Control.fmu
# 08:43:10.758 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Control.fmu to /tmp/Control4322859652371400786
# 08:43:10.825 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Control.fmu' to '/tmp/Control4322859652371400786'
# 08:43:10.828 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Control4322859652371400786/binaries/linux64/Control.so
# 08:43:10.829 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Control4322859652371400786/binaries/linux64/Control.so
# 08:43:10.829 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140140704694624
# 08:43:10.829 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 71786615
# 08:43:10.830 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {e50d67b1-f0fd-4cb9-b790-439045eb253b}, NAME: baselineInstance
# 08:43:10.838 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 7911761
# 08:43:10.841 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {14d4dba8-0226-412e-8fda-5f49a32d04a2}, NAME: stimuliInstance
# 08:43:10.843 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1815034
# 08:43:10.843 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {126aa57a-b271-41f4-a011-9fd7bfeae4ea}, NAME: driveInstance
# 08:43:10.845 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1745766
# 08:43:10.845 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {7ef1310e-51ff-43f0-81ad-cd309eb2ca4f}, NAME: controlInstance
# 08:43:10.847 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1806028
# 08:43:11.213 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:11.214 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:11.215 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:11.215 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:11.216 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:11.216 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Stimuli.fmu, temp folder /tmp/Stimuli5800003627925475887
# 08:43:11.217 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Stimuli5800003627925475887
# 08:43:11.230 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:11.231 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Drive.fmu, temp folder /tmp/Drive12043118279900462021
# 08:43:11.231 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Drive12043118279900462021
# 08:43:11.241 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:11.241 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu, temp folder /tmp/MODELICA_Demo705253361978075827
# 08:43:11.242 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/MODELICA_Demo705253361978075827
# 08:43:11.251 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:11.251 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Control.fmu, temp folder /tmp/Control4322859652371400786
# 08:43:11.252 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Control4322859652371400786
# 08:43:11.257 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 825563353 PT0.825557777S
#
# 08:43:13.224 [main] DEBUG org.intocps.maestro.Mabl - Frameworks: [FMI2]
# 08:43:13.617 [main] INFO  org.intocps.maestro.MablSpecificationGenerator - 	Imports [ JacobianStepBuilder , JacobianStepBuilder3 , Initializer , DebugLogging , TypeConverter , DataWriter , FMI2 , FMI3 , Math , ArrayUtil , Logger , BooleanLogic , MEnv ]
# 08:43:13.860 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Initializer - 0.0.0
# 08:43:13.860 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: DebugLogging - 0.0.1
# 08:43:13.860 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder3 - 1.1.0
# 08:43:13.861 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: TypeConverter - 0.0.1
# 08:43:13.861 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: JacobianStepBuilder - 1.1.0
# 08:43:13.861 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: FixedStep - 0.0.1
# 08:43:13.861 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Located plugins: Sigver - 0.0.1
# 08:43:13.872 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - The following plugins will be used for unfolding: [Initializer-0.0.0,DebugLogging-0.0.1,JacobianStepBuilder3-1.1.0,TypeConverter-0.0.1,JacobianStepBuilder-1.1.0]
# 08:43:13.873 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Plugins declared functions:
# [
# Initializer-0.0.0
# 	void initialize(FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize_transfer(FMI2Component[] component, FMI2Component[] component, real startTime, real endTime, bool endTimeDefined),
# 	void initialize23(FMI2Component[] component, FMI3Instance[] instances, real startTime, real endTime, bool endTimeDefined),
# DebugLogging-0.0.1
# 	void enableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# 	void disableDebugLogging(FMI2Component component, string[] categories, uint categoriesSize),
# JacobianStepBuilder3-1.1.0
# 	void fixedStep3Size(FMI2Component[] component, FMI3Instance[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# TypeConverter-0.0.1
# 	void convertInteger2Boolean(int from, bool to),
# 	void convertReal2Boolean(real from, bool to),
# 	void convertBoolean2Real(bool from, real to),
# 	void convertBoolean2Integer(bool from, int to),
# JacobianStepBuilder-1.1.0
# 	void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void fixedStepSize(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined),
# 	void variableStepSize(FMI2Component[] component, real initSize, real startTime, real endTime, bool endTimeDefined)
# ]
# 08:43:13.917 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Externals [ initialize , fixedStepSizeTransfer ]
# 08:43:13.922 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'initialize' with unfoled statement 'initialize' from plugin: Initializer 0.0.0
# 08:43:13.974 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Setup experiment for all components
# 08:43:14.198 [main] DEBUG org.intocps.maestro.plugin.initializer.Initializer - Enter initialization Mode
# 08:43:14.252 [main] DEBUG org.intocps.maestro.MablSpecificationGenerator - Replacing external 'fixedStepSizeTransfer' with unfoled statement 'fixedStepSizeTransfer' from plugin: JacobianStepBuilder 1.1.0
# 08:43:14.280 [main] INFO  org.intocps.maestro.plugin.JacobianStepBuilder - Unfolding with jacobian step: void fixedStepSizeTransfer(FMI2Component[] component, real stepSize, real startTime, real endTime, bool endTimeDefined)
# 08:43:14.280 [main] DEBUG org.intocps.maestro.plugin.JacobianStepBuilder - Activated mode transfer
# 08:43:16.283 [main] DEBUG org.intocps.maestro.Mabl - Type checking
# 08:43:16.475 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Starting Mable Interpreter...
# 08:43:16.488 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Stimuli.fmu
# 08:43:16.488 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Stimuli.fmu to /tmp/Stimuli11726248780996197643
# 08:43:16.615 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Stimuli.fmu' to '/tmp/Stimuli11726248780996197643'
# 08:43:16.620 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Stimuli11726248780996197643/binaries/linux64/Stimuli.so
# 08:43:16.621 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loading library: lib/Linux-amd64/libfmuapi.so
# 08:43:16.622 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracting library from: lib/Linux-amd64/libfmuapi.so
# 08:43:16.629 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLibraryLoader - Extracted library: /tmp/jnifmuapi4943048638512978128/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:43:16.631 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmuLibraryLoader - Loaded Library file: /tmp/jnifmuapi4943048638512978128/jnifmuapi-Linux-amd64/libfmuapi.so
# 08:43:16.632 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Stimuli11726248780996197643/binaries/linux64/Stimuli.so
# 08:43:16.632 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140179554780752
# 08:43:16.633 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 145727056
# 08:43:16.633 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Drive.fmu
# 08:43:16.634 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Drive.fmu to /tmp/Drive7936245388924477869
# 08:43:16.717 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Drive.fmu' to '/tmp/Drive7936245388924477869'
# 08:43:16.726 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Drive7936245388924477869/binaries/linux64/Drive.so
# 08:43:16.726 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Drive7936245388924477869/binaries/linux64/Drive.so
# 08:43:16.726 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140179553487216
# 08:43:16.727 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 93814256
# 08:43:16.727 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu
# 08:43:16.727 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu to /tmp/MODELICA_Demo11973446392057178089
# 08:43:16.800 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu' to '/tmp/MODELICA_Demo11973446392057178089'
# 08:43:16.806 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/MODELICA_Demo11973446392057178089/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:43:16.809 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/MODELICA_Demo11973446392057178089/binaries/linux64/MODELICA_Demo_ControlledElectricDrive.so
# 08:43:16.809 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140179553476144
# 08:43:16.809 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 82348903
# 08:43:16.810 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Load FMU /app/fmus/Control.fmu
# 08:43:16.810 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracting: /app/fmus/Control.fmu to /tmp/Control17677461319880688828
# 08:43:16.877 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Extracted '/app/fmus/Control.fmu' to '/tmp/Control17677461319880688828'
# 08:43:16.879 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loading FMU library: /tmp/Control17677461319880688828/binaries/linux64/Control.so
# 08:43:16.880 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Successfully loaded FMU library: /tmp/Control17677461319880688828/binaries/linux64/Control.so
# 08:43:16.880 [main] DEBUG org.intocps.fmi.jnifmuapi.shared.NativeLoadManager - Loaded library into DLL pointer: 140179553477152
# 08:43:16.880 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Interpretation load took: 70463048
# 08:43:16.880 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {e50d67b1-f0fd-4cb9-b790-439045eb253b}, NAME: baselineInstance
# 08:43:16.887 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 6177077
# 08:43:16.889 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {14d4dba8-0226-412e-8fda-5f49a32d04a2}, NAME: stimuliInstance
# 08:43:16.891 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1863216
# 08:43:16.892 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {126aa57a-b271-41f4-a011-9fd7bfeae4ea}, NAME: driveInstance
# 08:43:16.893 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1415357
# 08:43:16.893 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - Loading native FMU. GUID: {7ef1310e-51ff-43f0-81ad-cd309eb2ca4f}, NAME: controlInstance
# 08:43:16.895 [main] INFO  org.intocps.maestro.interpreter.Interpreter - Interpretation instantiate took: 1244594
# 08:43:17.260 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:17.261 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:17.261 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:17.262 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - freeInstance
# 08:43:17.262 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:17.263 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Stimuli.fmu, temp folder /tmp/Stimuli11726248780996197643
# 08:43:17.263 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Stimuli11726248780996197643
# 08:43:17.278 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:17.278 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Drive.fmu, temp folder /tmp/Drive7936245388924477869
# 08:43:17.278 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Drive7936245388924477869
# 08:43:17.290 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:17.291 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/MODELICA_Demo.ControlledElectricDrive.fmu, temp folder /tmp/MODELICA_Demo11973446392057178089
# 08:43:17.291 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/MODELICA_Demo11973446392057178089
# 08:43:17.301 [main] DEBUG org.intocps.maestro.interpreter.Interpreter - unload
# 08:43:17.302 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - UnLoad FMU /app/fmus/Control.fmu, temp folder /tmp/Control17677461319880688828
# 08:43:17.302 [main] DEBUG org.intocps.fmi.jnifmuapi.NativeFmu - Deleting temp folder /tmp/Control17677461319880688828
# 08:43:17.308 [main] INFO  org.intocps.maestro.interpreter.MableInterpreter - Interpretation time: 832318039 PT0.832312949S
#
# errors = [np.float64(2.6448263695703407), np.float64(5.964981643110422), np.float64(8.026671131233565), np.float64(8.21990534534943)]
# execution_times = [6.701955795288086, 5.927386522293091, 5.877979040145874, 6.0473620891571045]

# %%
# Plot the results

fig, axs = plt.subplots(2, 1)

axs[0].plot(step_sizes, errors, label="Error")
axs[0].legend()

axs[1].plot(step_sizes, execution_times, label="Execution time")
axs[1].legend()

# Adjust spacing between subplots
plt.tight_layout()
